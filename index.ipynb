# %%
# SQL Interview Questions  - Quiz


## Introduction

This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line. 

## Question 1

What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?

Type your answer below this line:
1. Null
2. Interger
3. Text
4. Blob

Yes we can use common sql datatypes such as VARCHAR, CHAR, BOOLEAN, DATE TIME
_______________________________________________________________________________________________________________________________





## Question 2

Explain the relationship between **Primary Keys** and **Foreign Keys**.

Type your answer below this line:
Their relationship ensures referential integrity. We can't have a foreign key value that does not exist as a primary key in the referenced table.

_______________________________________________________________________________________________________________________________





## Question 3

Explain the different types of relationships entities can have in a SQL database. 

Type your answer below this line:
1. One-to-One: Each record in Table A relates to exactly one record in Table B
2. One-to-Many: A record in Table A can relate to multiple records in Table B, but each record in Table B relates to only one record in      Table A 
3. Many-to-Many: multiple entries for the shared field in both tables
_______________________________________________________________________________________________________________________________


## Question 4

Explain the various types of JOINs possible with SQL. 

Type your answer below this line:
1. Inner Join: Returns rows that have matching values in both tables
2. Left Outer Join : Returns all rows from the left table, plus matching rows from the right table
3. Right Outer Join: Returns all rows from the right table, plus matching rows from the left table
4. Full Outer Join : Returns rows when there is a match in either table.
_______________________________________________________________________________________________________________________________



## Question 5

Explain the relationship between Aggregate functions and GROUP BY statements.

Type your answer below this line:

Without GROUP BY an Aggregate function treats the entire result set as one group. With GROUP BY the entire aggregate is calculated separately for each group
_______________________________________________________________________________________________________________________________



## Question 6

What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?


Type your answer below this line:
In a many-to-many relationship, associative entities act as linkages between two main tables.
_______________________________________________________________________________________________________________________________



## Summary

In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
